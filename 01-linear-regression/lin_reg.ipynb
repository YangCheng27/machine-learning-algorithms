# %%
import lin_reg
import matplotlib.pyplot as plt

# %% [markdown]
# Load data from skicit-learn datasets

# %%
df = lin_reg.load_data()
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
lin_reg.correlation_map(df)
# Out:
# /Users/kycheng/Desktop/Programming/github/machine-learning-algorithms/01-linear-regression/lin_reg.py:30: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
lin_reg.correlation_map3(df)
corr = df.corr()
corr['MedHouseVal'].sort_values(ascending=True)
# Out:
# Latitude      -0.144160
# AveBedrms     -0.046701
# Longitude     -0.045967
# Population    -0.024650
# AveOccup      -0.023737
# HouseAge       0.105623
# AveRooms       0.151948
# MedInc         0.688075
# MedHouseVal    1.000000
# Name: MedHouseVal, dtype: float64
